# %%
# загружаем словарь
# !!! словарь должен быть в той же папке, что и этот файл !!!
from lxml import etree
with open('fra-eng.tei', encoding='utf-8') as f:
    text = f.read()
root = etree.fromstring(text)

# %%
# найдём все узлы с тэгом entry
entries = root.xpath('.//entry')

# проверяем количество вхождений
print(len(entries), 'entries')
# Out:
# 8505 entries

# %%
# загружаем датафрейм с формами глаголов третьей группы
import pandas as pd
df = pd.read_csv('third_group_verbs_table.csv')
third_group_verbs_list = [i for i in df.lemma]

# %%
# функция, распределяющая все глаголы по группам
first_group = []
second_group = []
lost_verbs = []
unidentified_verbs = []
def identify(w):
    if w in third_group_verbs_list:
        return ['3nd group',
                df.présent[df.lemma==w][third_group_verbs_list.index(w)],
                df.passécomposé[df.lemma==w][third_group_verbs_list.index(w)],
                df.futur[df.lemma==w][third_group_verbs_list.index(w)],
                df.subjonctif[df.lemma==w][third_group_verbs_list.index(w)]]
    elif (w[:6] == 'se la '):
        return ['is conjugated like ' + w[6:].split(' ')[0]]
    elif (w[:3] == 'se '):
        return ['is conjugated like ' + w[3:].split(' ')[0]]
    elif (w[:5] == "s’en "):
        return ['is conjugated like ' + w[5:].split(' ')[0]]
    elif (w[:2] == "s’"):
        return ['is conjugated like ' + w[2:].split(' ')[0]]
    elif (w[-2:] == 'ir' or w[-2:] == 'ïr')  and ' ' not in w:
        second_group.append(w)
        return ['2nd group']
    elif w[-2:] == 'er' and ' ' not in w:
        first_group.append(w)
        return ['1st group']
    elif ' ' not in w:
        return []
        lost_verbs.append(w)
    else:
        return []
        unidentified_verbs.append(w)

# %%
all_verbs_elements_list = [i for i in entries if i.xpath('.//pos/text()') == ['v']]
for v in all_verbs_elements_list:
    w = str(v.xpath('.//orth/text()'))[2:-2]
    print(w, identify(w))
# Out:
# abaisser ['1st group']
# abandonner ['1st group']
# abasourdir ['2nd group']
# abattre ['3nd group', 'j`abats, nous abattons', 'j`ai abattu', 'j`abattrai', 'que j`abatte']
# abdiquer ['1st group']
# abhorrer ['1st group']
# abjurer ['1st group']
# abolir ['2nd group']
# abominer ['1st group']
# abonder ['1st group']
# aborder ['1st group']
# aboucher ['1st group']
# abouler ['1st group']
# abouter ['1st group']
# aboutir ['2nd group']
# aboyer ['1st group']
# aboyer à []
# abreuver ['1st group']
# abriter ['1st group']
# abroger ['1st group']
# abréger ['1st group']
# absorber ['1st group']
# abstraire ['3nd group', 'j`abstrais, nous abstrayons', 'j`ai abstrait', 'j`abstrairai', 'que j`abstraie, que nous abstrayions']
# abuser ['1st group']
# abêtir ['2nd group']
# abîmer ['1st group']
# accaparer ['1st group']
# accepter ['1st group']
# acclamer ['1st group']
# accommoder ['1st group']
# accomplir ['2nd group']
# accorder ['1st group']
# accoter ['1st group']
# accoucher ['1st group']
# accoupler ['1st group']
# accoutumer ['1st group']
# accrocher ['1st group']
# accroître ['3nd group', 'j`accrois, nous accroissons', 'j`ai accru', 'j`accroîtrai', 'que j`accroisse']
# accréditer ['1st group']
# accueillir ['3nd group', 'j`accueille', 'j`ai accueilli', 'j`accueillerai', 'que j`accueille']
# accumuler ['1st group']
# accuser ['1st group']
# accélerer ['1st group']
# accélérer ['1st group']
# achever ['1st group']
# achopper ['1st group']
# acidifier ['1st group']
# acquitter ['1st group']
# acquérir ['3nd group', 'j`acquiers, nous acquérons', 'j`ai acquis', 'j`acquerrai', 'que j`acquière']
# acquérir péniblement []
# actionner ['1st group']
# activer ['1st group']
# adapter ['1st group']
# additionner ['1st group']
# adhérer ['1st group']
# adjoindre ['3nd group', 'j`adjoins, nous adjoignons', 'j`ai adjoint', 'j`adjoindrai', 'que j`adjoigne']
# adjuger ['1st group']
# admettre ['3nd group', 'j`admets, nous admettons', 'j’ai admis', 'j`admettrai', 'que j`admette ']
# administrer ['1st group']
# admirer ['1st group']
# admonester ['1st group']
# adopter ['1st group']
# adorer ['1st group']
# adresser ['1st group']
# adresser la parole à []
# aduler ['1st group']
# affaiblir ['2nd group']
# affecter ['1st group']
# affermer ['1st group']
# afficher ['1st group']
# affiler ['1st group']
# affinier ['1st group']
# affirmer ['1st group']
# affliger ['1st group']
# affranchir ['2nd group']
# affronter ['1st group']
# agacer ['1st group']
# agglutiner ['1st group']
# aggraver ['1st group']
# agir ['2nd group']
# agir avec abnégation []
# agir avec affectation []
# agir en hypocrite []
# agir selon []
# agiter ['1st group']
# agoniser ['1st group']
# agrafer ['1st group']
# agrander ['1st group']
# agresser ['1st group']
# agripper ['1st group']
# agréer ['1st group']
# aider ['1st group']
# aigrir ['2nd group']
# aiguiller ['1st group']
# aiguiser ['1st group']
# aimer ['1st group']
# ajourner ['1st group']
# ajouter ['1st group']
# ajuster ['1st group']
# alarmer ['1st group']
# alerter ['1st group']
# alimenter ['1st group']
# allaiter ['1st group']
# aller ['3nd group', 'je vais, nous allons', 'je suis allé', "j'irai", "que j'aille, que nous allions"]
# aller en pélerinage []
# aller en véhicule []
# aller à la selle []
# allier ['1st group']
# allonger ['1st group']
# allouer ['1st group']
# allumer ['1st group']
# allécher ['1st group']
# alterner ['1st group']
# amadouer ['1st group']
# amender ['1st group']
# amener ['1st group']
# amoindrir ['2nd group']
# amplifier ['1st group']
# amputer ['1st group']
# amuser ['1st group']
# améliorer ['1st group']
# américaniser ['1st group']
# analyser ['1st group']
# animer ['1st group']
# annoncer ['1st group']
# annuler ['1st group']
# anticiper ['1st group']
# apercevoir ['3nd group', 'j`aperçois, nous apercevons', 'j’ai aperçu', 'j`apercevrai', 'que j`aperçoive, que nous apercevions']
# apitoyer ['1st group']
# apparaître ['3nd group', 'j`apparais, nous apparaissons', 'j’ai apparu', 'je apparaîtrai', 'que j`apparaisse']
# apparier ['1st group']
# appartenir ['3nd group', 'j`appartiens, nous appartenons', 'j`ai appartenu', 'j`appartiendrai', 'que j`appartienne']
# appeler ['1st group']
# applaudir ['2nd group']
# appliquer ['1st group']
# apporter ['1st group']
# apposer ['1st group']
# apprendre ['3nd group', 'j`apprends, nous apprenons', 'j’ai appris', 'j`apprendrai', 'que j`apprenne, que nous apprenions']
# apprendre par cœur []
# apprendre par l'expérience []
# apprendre à []
# apprendre à fond []
# apprivoiser ['1st group']
# approcher ['1st group']
# approuver ['1st group']
# apprécier ['1st group']
# apprêter ['1st group']
# appuyer ['1st group']
# appuyer en écrasant []
# appâter ['1st group']
# armer ['1st group']
# arracher ['1st group']
# arranger ['1st group']
# arrimer ['1st group']
# arriver ['1st group']
# arriver en flottant []
# arrondir ['2nd group']
# arrêter ['1st group']
# asphalter ['1st group']
# aspirer ['1st group']
# aspirer à []
# assaillir ['3nd group', 'j`assaille', 'j`ai assailli', 'j`assaillerai', 'que j`assaille']
# assainir ['2nd group']
# assaisonner ['1st group']
# assassiner ['1st group']
# assembler ['1st group']
# asseoir ['3nd group', 'j`assieds/j`assois, nous asseyons/nous assoyons', 'j`ai assis', 'j`assiérai/j`assoirai', 'que j`asseye/que j`assoie']
# assigner ['1st group']
# assimiler ['1st group']
# assister ['1st group']
# assister à []
# associer ['1st group']
# assoupir ['2nd group']
# assurer ['1st group']
# attacher ['1st group']
# attaquer ['1st group']
# atteindre ['3nd group', 'j`atteins, nous atteignons', 'j`ai atteint', 'j`atteindrai', 'que j`atteigne']
# atteler ['1st group']
# attendre ['3nd group', 'j`attends, nous attendons', 'j`ai attendu', 'j`attendrai', 'que j`attende']
# attenter ['1st group']
# atterrir ['2nd group']
# attester ['1st group']
# attirer ['1st group']
# attraper ['1st group']
# attribuer ['1st group']
# attrister ['1st group']
# augmenter ['1st group']
# augurer ['1st group']
# automatiser ['1st group']
# autoriser ['1st group']
# avaler ['1st group']
# avancer ['1st group']
# aventurer ['1st group']
# avertir ['2nd group']
# aveugler ['1st group']
# avoir ['3nd group', "j'ai, nous avons", "j'ai eu", "j'aurai", "que j'aie, que nous ayons"]
# avoir besoin de []
# avoir coutume []
# avoir faim []
# avoir honte []
# avoir l'air de []
# avoir l'habitude de []
# avoir le hoquet []
# avoir lieu []
# avoir peur []
# avoir pitié []
# avoir pour but []
# avoir soif []
# avoir soin de []
# avoir un accident []
# avoir une dette []
# avorter ['1st group']
# avouer ['1st group']
# babiller ['1st group']
# badauder ['1st group']
# badiner ['1st group']
# bafouer ['1st group']
# bafouiller ['1st group']
# baigner ['1st group']
# bailler ['1st group']
# baiser ['1st group']
# baisser ['1st group']
# balancer ['1st group']
# balayer ['1st group']
# balbutier ['1st group']
# bamboucher ['1st group']
# bander ['1st group']
# bannir ['2nd group']
# banqueter ['1st group']
# baptiser ['1st group']
# baratter ['1st group']
# barboter ['1st group']
# barguigner ['1st group']
# barrer ['1st group']
# barricader ['1st group']
# baser ['1st group']
# batailler ['1st group']
# batifoler ['1st group']
# battre ['3nd group', 'je bats, nous battons', 'j`ai battu', 'je battrai', 'que je batte']
# bavarder ['1st group']
# bayer aux corneilles []
# bercer ['1st group']
# biffer ['1st group']
# blasphémer ['1st group']
# blesser ['1st group']
# bluffer ['1st group']
# boire ['3nd group', 'je bois, nous buvons', "j'ai bu", 'je boirai', 'que je boive, que nous buvions']
# bombarder ['1st group']
# boucher ['1st group']
# boucler ['1st group']
# bouder ['1st group']
# bouger ['1st group']
# bouillir ['3nd group', 'je bous, nous bouillons', 'j`ai bouilli', 'je bouillirai', 'que je bouille']
# bourdonner ['1st group']
# boxer ['1st group']
# brandir ['2nd group']
# braser ['1st group']
# braver ['1st group']
# bredouiller ['1st group']
# briller ['1st group']
# briser ['1st group']
# broder ['1st group']
# brouiller ['1st group']
# broyer ['1st group']
# brûler ['1st group']
# buller ['1st group']
# buriner ['1st group']
# butter ['1st group']
# bâiller ['1st group']
# bâtir ['2nd group']
# béer ['1st group']
# bégayer ['1st group']
# bénir ['2nd group']
# bêler ['1st group']
# cacher ['1st group']
# calculer ['1st group']
# calomnier ['1st group']
# cancaner ['1st group']
# capturer ['1st group']
# causer ['1st group']
# cautionner ['1st group']
# censurer ['1st group']
# certifier ['1st group']
# cesser ['1st group']
# chagriner ['1st group']
# changer ['1st group']
# chanter ['1st group']
# chaperonner ['1st group']
# charger ['1st group']
# charpenter ['1st group']
# chasser ['1st group']
# chatouiller ['1st group']
# chauffer ['1st group']
# chercher ['1st group']
# chevaucher ['1st group']
# chicaner ['1st group']
# choisir ['2nd group']
# choquer ['1st group']
# choyer ['1st group']
# chuchoter ['1st group']
# circuler ['1st group']
# cirer ['1st group']
# ciseler ['1st group']
# citer ['1st group']
# clamer ['1st group']
# clapoter ['1st group']
# claquer ['1st group']
# clouer ['1st group']
# coiffer ['1st group']
# collectionner ['1st group']
# coller ['1st group']
# combattre ['3nd group', 'je combats, nous combattons', 'j`ai combattu', 'je combattrai', 'que je combatte']
# combler ['1st group']
# commander ['1st group']
# commencer ['1st group']
# communiquer ['1st group']
# commuter ['1st group']
# comparer ['1st group']
# compatir ['2nd group']
# compenser ['1st group']
# compliquer ['1st group']
# comploter ['1st group']
# compléter ['1st group']
# comporter ['1st group']
# composer ['1st group']
# comprendre ['3nd group', 'je comprends, nous comprenons', 'j’ai compris', 'je comprendrai', 'que je comprenne, que nous comprenions']
# compter ['1st group']
# concerner ['1st group']
# concevoir ['3nd group', 'je conçois, nous concevons', 'j’ai conçu', 'je concevrai', 'que je conçoive, que nous concevions']
# conclure ['3nd group', 'je conclus', 'j`ai conclu', 'je conclurai', 'que je conclue']
# concorder ['1st group']
# concourir ['3nd group', 'je concours ', 'j’ai concouru', 'je concourrai', 'que je concoure']
# condamner ['1st group']
# conduire ['3nd group', 'je conduis, nous conduisons', 'j`ai conduit', 'je conduirai', 'que je conduise']
# confectionner ['1st group']
# confier ['1st group']
# confire ['3nd group', 'je confis', 'j`ai confit', 'je confirai', 'que je confise']
# confirmer ['1st group']
# confisquer ['1st group']
# confondre ['3nd group', 'je confonds', 'j`ai confondu', 'je confondrai', 'que je confonde']
# conjecturer ['1st group']
# connaître ['3nd group', 'je connais, nous connaissons', 'j’ai connu', 'je connaîtrai', 'que je connaisse']
# connecter ['1st group']
# conquérir ['3nd group', 'je conquiers, nous conquérons', 'j`ai conquis', 'je conquerrai', 'que je conquière']
# consacrer ['1st group']
# conseiller ['1st group']
# consentir ['3nd group', 'je consens, nous consentons', 'j`ai consenti', 'je consentirai', 'que je consente']
# conserver ['1st group']
# considérer ['1st group']
# consister ['1st group']
# consoler ['1st group']
# consommer ['1st group']
# constater ['1st group']
# consterner ['1st group']
# construire ['3nd group', 'je construis, nous construisons', 'j`ai construit', 'je construirai', 'que je construise']
# consulter ['1st group']
# consumer ['1st group']
# contempler ['1st group']
# contenir ['3nd group', 'je contiens, nous contenons', 'j`ai contenu', 'je contiendrai', 'que je contienne']
# contenter ['1st group']
# conter ['1st group']
# conter fleurette []
# contester ['1st group']
# continuer ['1st group']
# contracter ['1st group']
# contraindre ['3nd group', 'je contrains, nous contraignons', 'j`ai contraint', 'je contraindrai', 'que je contraigne']
# contribuer ['1st group']
# convaincre ['3nd group', 'je convaincs, nous convainquons', 'j`ai convaincu', 'je convaincrai', 'que je convainque']
# convenir ['3nd group', 'je conviens, nous convenons', 'j`ai convenu', 'je conviendrai', 'que je convienne, que nous convenions']
# convertir ['2nd group']
# copier ['1st group']
# correspondre ['3nd group', 'je corresponds', 'j`ai correspondu', 'je correspondrai', 'que je corresponde']
# correspondre à []
# corriger ['1st group']
# corrompre ['3nd group', 'je corromps', 'j`ai corrompu', 'je corromprai', 'que je corrompe']
# coucher ['1st group']
# coudre ['3nd group', 'je couds, nous cousons', 'j`ai cousu', 'je coudrai', 'que je couse']
# couler ['1st group']
# couper ['1st group']
# couper avec des ciseaux []
# coupler ['1st group']
# courber ['1st group']
# courir ['3nd group', 'je cours ', 'j’ai couru', 'je courrai', 'que je coure']
# couronner ['1st group']
# couver ['1st group']
# couvrir ['3nd group', 'je couvre, nous couvrons', 'j’ai couvert', 'je couvrirai', 'que je couvre']
# coïncider ['1st group']
# coïter ['1st group']
# coûter ['1st group']
# cracher ['1st group']
# craindre ['3nd group', 'je crains, nous craignons', 'j`ai craint', 'je craindrai', 'que je craigne']
# craquer ['1st group']
# creuser ['1st group']
# crever ['1st group']
# crier ['1st group']
# critiquer ['1st group']
# croasser ['1st group']
# croire ['3nd group', 'je crois, nous croyons', 'j’ai cru', 'je croirai', 'que je croie, que nous croyions']
# croiser ['1st group']
# croître ['3nd group', 'je croîs, nous croissons', 'j`ai crû', 'je croîtrai', 'que je croisse']
# créer ['1st group']
# cueillir ['3nd group', 'je cueille', 'j`ai cueilli', 'je cueillerai', 'que je cueille']
# cuire ['3nd group', 'je cuis, nous cuisons', 'j`ai cuit', 'je cuirai', 'que je cuise']
# cuisiner ['1st group']
# cultiver ['1st group']
# céder ['1st group']
# célébrer ['1st group']
# dactylographier ['1st group']
# démasquer ['1st group']
# danser ['1st group']
# dater ['1st group']
# demander ['1st group']
# demeurer ['1st group']
# descendre ['3nd group', 'je descends, nous descendons', 'j`ai descendu/je suis descendu', 'je descendrai', 'que je descende']
# descendre en rappel []
# dessiner ['1st group']
# destiner ['1st group']
# devenir ['3nd group', 'je deviens, nous devenons', 'je suis devenu', 'je deviendrai', 'que je devienne, que nous devenions']
# deviner ['1st group']
# devoir ['3nd group', 'je dois, nous devons', 'j`ai dû', 'je devrai', 'que je doive, que nous devions']
# dicter ['1st group']
# diffamer ['1st group']
# diffuser ['1st group']
# différer ['1st group']
# digérer ['1st group']
# diluer ['1st group']
# diminuer ['1st group']
# dire ['3nd group', 'je dis, nous disons', 'j’ai dit', 'je dirai', 'que je dise ']
# dire adieu []
# diriger ['1st group']
# discerner ['1st group']
# discuter ['1st group']
# disparaître ['3nd group', 'je disparais, nous disparaissons', 'j’ai disparu', 'je disparaîtrai', 'que je disparaisse']
# dispenser ['1st group']
# disperser ['1st group']
# disposer ['1st group']
# disposer de []
# disputer ['1st group']
# dissiper ['1st group']
# distinguer ['1st group']
# distraire ['3nd group', 'je distrais, nous distrayons', 'j`ai distrait', 'je distrairai', 'que je distraie, que nous distrayions']
# distribuer ['1st group']
# diviser ['1st group']
# dominer ['1st group']
# donner ['1st group']
# donner l'assaut []
# donner son accord []
# dorer ['1st group']
# sˈinsurger ['1st group']
# se dorer ['is conjugated like dorer']
# dorloter ['1st group']
# dormir ['3nd group', 'je dors, nous dormons', 'j`ai dormi', 'je dormirai', 'que je dorme']
# doubler ['1st group']
# douter ['1st group']
# drainer ['1st group']
# dresser ['1st group']
# durcir ['2nd group']
# durer ['1st group']
# débarquer ['1st group']
# débarrasser ['1st group']
# débattre ['3nd group', 'je débats, nous débattons', 'j`ai débattu', 'je débattrai', 'que je débatte']
# débiter ['1st group']
# déborder ['1st group']
# débuter ['1st group']
# décharger ['1st group']
# déchirer ['1st group']
# décider ['1st group']
# déclarer ['1st group']
# décorer ['1st group']
# découper ['1st group']
# découvrir ['3nd group', 'je découvre, nous découvrons', 'j’ai découvert', 'je découvrirai', 'que je découvre']
# décrire ['3nd group', 'je décris, nous décrivons', 'j’ai décrit', 'je décrirai', 'que je décrive']
# décéder ['1st group']
# dédaigner ['1st group']
# dédier ['1st group']
# déduire ['3nd group', 'je déduis, nous déduisons', 'j`ai déduit', 'je déduirai', 'que je déduise']
# défendre ['3nd group', 'je défends, nous défendons', 'j`ai défendu', 'je défendrai', 'que je défende']
# défiler ['1st group']
# déféquer ['1st group']
# dégager ['1st group']
# dégeler ['1st group']
# délirer ['1st group']
# délivrer ['1st group']
# déléguer ['1st group']
# démanger ['1st group']
# démarrer ['1st group']
# démissioner ['1st group']
# démolir ['2nd group']
# démontrer ['1st group']
# déménager ['1st group']
# dénoncer ['1st group']
# dépasser ['1st group']
# dépeindre ['3nd group', 'je dépeins, nous dépeignons', 'j`ai dépeint', 'je dépeindrai', 'que je dépeigne']
# dépendre ['3nd group', 'je dépends, nous dépendons', 'j`ai dépendu', 'je dépendrai', 'que je dépende']
# dépenser ['1st group']
# déployer ['1st group']
# déposer ['1st group']
# dépouiller ['1st group']
# déranger ['1st group']
# dériver ['1st group']
# dérober ['1st group']
# désespérer ['1st group']
# déshabiller ['1st group']
# désigner ['1st group']
# désirer ['1st group']
# désoler ['1st group']
# détacher ['1st group']
# déterminer ['1st group']
# détester ['1st group']
# détourner ['1st group']
# détruire ['3nd group', 'je détruis, nous détruisons', 'j`ai détruit', 'je détruirai', 'que je détruise']
# détériorer ['1st group']
# développer ['1st group']
# dévier ['1st group']
# dévorer ['1st group']
# dévoyer ['1st group']
# effacer ['1st group']
# effacer en grattant []
# effleurer ['1st group']
# embaucher ['1st group']
# embaumer ['1st group']
# embellir ['2nd group']
# embrasser ['1st group']
# emmailloter ['1st group']
# employer ['1st group']
# emprunter ['1st group']
# emprunter sur gages []
# empêcher ['1st group']
# empêtrer ['1st group']
# enchanter ['1st group']
# enchaîner ['1st group']
# endommager ['1st group']
# enduire ['3nd group', 'j`enduis, nous enduisons', 'j`ai enduit', 'j`enduirai', 'que j`enduise']
# endurer ['1st group']
# enflammer ['1st group']
# enfuir ['2nd group']
# engendrer ['1st group']
# enjoindre ['3nd group', 'j`enjoins, nous enjoignons', 'j`ai enjoint', 'j`enjoindrai', 'que j`enjoigne']
# ennuyer ['1st group']
# enquêter ['1st group']
# enregistrer ['1st group']
# enrichir ['2nd group']
# enrouler ['1st group']
# enrôler ['1st group']
# enseigner ['1st group']
# ensorceler ['1st group']
# entamer ['1st group']
# entasser ['1st group']
# entendre ['3nd group', 'j`entends, nous entendons', 'j`ai entendu', 'j`entendrai', 'que j`entende']
# entonner ['1st group']
# entortiller ['1st group']
# entourer ['1st group']
# entraîner ['1st group']
# entraîner hors du droit chemin []
# entreprendre ['3nd group', 'j`entreprends, nous entreprenons', 'j’ai entrepris', 'j`entreprendrai', 'que j`entreprenne, que nous entreprenions']
# entrer ['1st group']
# envahir ['2nd group']
# envier ['1st group']
# envisager ['1st group']
# envoyer ['1st group']
# errer ['1st group']
# espérer ['1st group']
# esquisser ['1st group']
# essayer ['1st group']
# essuyer ['1st group']
# estampiller ['1st group']
# estimer ['1st group']
# examiner ['1st group']
# exceller ['1st group']
# excepter ['1st group']
# exciter ['1st group']
# excuser ['1st group']
# exempter ['1st group']
# exercer ['1st group']
# exhaler un odeur []
# exhorter ['1st group']
# exiger ['1st group']
# exiler ['1st group']
# exister ['1st group']
# expliquer ['1st group']
# exploiter ['1st group']
# explorer ['1st group']
# exploser ['1st group']
# exprimer ['1st group']
# expédier ['1st group']
# exterminer ['1st group']
# exulter ['1st group']
# exécuter ['1st group']
# fabriquer ['1st group']
# faciliter ['1st group']
# faire ['3nd group', 'je fais, nous faisons', 'j’ai fait', 'je ferai', 'que je fasse, que nous fassions']
# faire accepter []
# faire allusion []
# faire appel []
# faire attention à []
# faire avancer []
# faire banqueroute []
# faire cadeau []
# faire cesser []
# faire cuire au four []
# faire du bruit []
# faire du bruit avec les lèvres []
# faire du jogging []
# faire escale à []
# faire fondre []
# faire glisser []
# faire l'acteur []
# faire l'amour []
# faire la cour []
# faire la noce []
# faire le courtage []
# faire le malin []
# faire les cent pas []
# faire naître []
# faire part de []
# faire paître []
# faire pipi []
# faire ses adieux []
# faire son nid []
# faire tomber []
# faire tournoyer []
# faire un bruit de succion []
# falloir ['3nd group', 'il faut', 'il a fallu', 'il faudra', 'qu`il faille']
# falsifier ['1st group']
# fanfarroner ['1st group']
# fatiguer ['1st group']
# faucher ['1st group']
# fausser ['1st group']
# fendre ['3nd group', 'je fends, nous fendons', 'j`ai fendu', 'je fendrai', 'que je fende']
# feuilleter ['1st group']
# fier ['1st group']
# filler la laine []
# filtrer ['1st group']
# finir ['2nd group']
# fixer ['1st group']
# flageller ['1st group']
# flairer ['1st group']
# flamber ['1st group']
# flatter ['1st group']
# fleurir ['2nd group']
# flirter ['1st group']
# flotter ['1st group']
# fléchir ['2nd group']
# foncer ['1st group']
# fonctionner ['1st group']
# fonder ['1st group']
# fondre ['3nd group', 'je fonds', 'j`ai fondu', 'je fondrai', 'que je fonde']
# forcer ['1st group']
# forer ['1st group']
# forger ['1st group']
# former ['1st group']
# formuler ['1st group']
# fouetter ['1st group']
# fouiller ['1st group']
# fouler aux pieds []
# fourmiller ['1st group']
# fournir ['2nd group']
# fourrer ['1st group']
# foutre ['3nd group', 'je fous, nous foutons', 'j`ai foutu', 'je foutrai', 'que je foute']
# fracasser ['1st group']
# fraiser ['1st group']
# frapper ['1st group']
# frauder ['1st group']
# freiner ['1st group']
# frire ['3nd group', 'je fris', 'j`ai frit', 'je frirai', 'que je frise']
# friser ['1st group']
# froisser ['1st group']
# frotter ['1st group']
# fréquenter ['1st group']
# fuir ['3nd group', 'je fuis, nous fuyons', 'j’ai fui', 'je fuirai', 'que je fuie, que nous fuyions']
# fumer ['1st group']
# fusiller ['1st group']
# féliciter ['1st group']
# fêter ['1st group']
# fôlatrer ['1st group']
# gagner ['1st group']
# galoper ['1st group']
# gambader ['1st group']
# garantir ['2nd group']
# garder ['1st group']
# garer ['1st group']
# garnir ['2nd group']
# gaspiller ['1st group']
# gazouiller ['1st group']
# geler ['1st group']
# germer ['1st group']
# glisser ['1st group']
# glisser comme une anguille []
# glorifier ['1st group']
# gonfler ['1st group']
# gouverner ['1st group']
# goûter ['1st group']
# grandir ['2nd group']
# gratter ['1st group']
# graver ['1st group']
# gravir ['2nd group']
# greffer ['1st group']
# griffer ['1st group']
# griller ['1st group']
# grimper ['1st group']
# grincer ['1st group']
# grogner ['1st group']
# gronder ['1st group']
# grossir ['2nd group']
# grouiller ['1st group']
# guerroyer ['1st group']
# guetter ['1st group']
# guider ['1st group']
# guérir ['2nd group']
# gâcher ['1st group']
# gâter ['1st group']
# gémir ['2nd group']
# gêner ['1st group']
# habiller ['1st group']
# habiter ['1st group']
# habituer ['1st group']
# hacher ['1st group']
# haleter ['1st group']
# hausser ['1st group']
# hausser les épaules []
# haïr ['2nd group']
# hennir ['2nd group']
# hente []
# herser ['1st group']
# heurter ['1st group']
# honorer ['1st group']
# hoqueter ['1st group']
# humilier ['1st group']
# hurler ['1st group']
# hypnotiser ['1st group']
# hâter ['1st group']
# hérisser ['1st group']
# hériter ['1st group']
# hésiter ['1st group']
# identifier ['1st group']
# ignorer ['1st group']
# illuminer ['1st group']
# illustrer ['1st group']
# imaginer ['1st group']
# imiter ['1st group']
# immerger ['1st group']
# impliquer ['1st group']
# implorer ['1st group']
# importer ['1st group']
# imposer ['1st group']
# imprimer ['1st group']
# improviser ['1st group']
# inaugurer ['1st group']
# inciter ['1st group']
# incliner ['1st group']
# indigner ['1st group']
# indiquer ['1st group']
# infecter ['1st group']
# influer ['1st group']
# informer ['1st group']
# infuser ['1st group']
# injecter ['1st group']
# inonder ['1st group']
# inscrire ['3nd group', 'j`inscris, nous inscrivons', 'j`ai inscrit', 'j`inscrirai', 'que j`inscrive']
# insinuer ['1st group']
# insister ['1st group']
# inspecter ['1st group']
# inspirer ['1st group']
# installer ['1st group']
# instruire ['3nd group', 'je instruis, nous instruisons', 'j`ai instruit', 'je instruirai', 'que je instruise']
# insulter ['1st group']
# interdire ['3nd group', 'j`interdis, nous interdisons', 'j’ai interdit', 'j`interdirai', 'que j`interdise ']
# intéger ['1st group']
# interpeller ['1st group']
# interpréter ['1st group']
# interroger ['1st group']
# interrompre ['3nd group', 'j`interromps', 'j`ai interrompu', 'j`interromprai', 'que j`interrompe']
# intervenir ['3nd group', 'je interviens, nous intervenons', 'je suis intervenu', 'je interviendrai', 'que je intervienne, que nous intervenions']
# intriguer ['1st group']
# introduire ['3nd group', 'j`introduis, nous introduisons', 'j`ai introduit', 'j`introduirai', 'que j`introduise']
# intéresser ['1st group']
# inventer ['1st group']
# investir ['2nd group']
# inviter ['1st group']
# invoquer ['1st group']
# irriter ['1st group']
# isoler ['1st group']
# jaillir ['2nd group']
# jaser ['1st group']
# jeter ['1st group']
# jeûner ['1st group']
# joindre ['3nd group', 'je joins, nous joignons', 'j`ai joint', 'je joindrai', 'que je joigne']
# joncher ['1st group']
# jongler ['1st group']
# jouer ['1st group']
# jouir ['2nd group']
# juger ['1st group']
# jurer ['1st group']
# labourer ['1st group']
# laisser ['1st group']
# lancer ['1st group']
# lasser ['1st group']
# laver ['1st group']
# lever ['1st group']
# libérer ['1st group']
# licencier ['1st group']
# lier ['1st group']
# limer ['1st group']
# limiter ['1st group']
# liquider ['1st group']
# lire ['3nd group', 'je lis', 'j’ai lu', 'je lirai', 'que je lise ']
# livrer ['1st group']
# loger ['1st group']
# loucher ['1st group']
# louer ['1st group']
# luire ['3nd group', 'je luis', 'j`ai lui', 'je luirai', 'que je luise']
# luter ['1st group']
# lutter ['1st group']
# lâcher ['1st group']
# lécher ['1st group']
# maintenir ['3nd group', 'je maintiens, nous maintenons', 'j`ai maintenu', 'je maintiendrai', 'que je maintienne']
# maitriser ['1st group']
# maltraiter ['1st group']
# manger ['1st group']
# manier ['1st group']
# manifester ['1st group']
# manquer ['1st group']
# maquiller ['1st group']
# marchander ['1st group']
# marcher ['1st group']
# marier ['1st group']
# marquer ['1st group']
# massacrer ['1st group']
# masser ['1st group']
# maudire ['3nd group', 'je maudis, nous maudissons', 'j’ai maudit', 'je maudirai', 'que je maudisse ']
# maçonner ['1st group']
# menacer ['1st group']
# mendier ['1st group']
# mener ['1st group']
# mentionner ['1st group']
# mentir ['3nd group', 'je mens, nous mentons', 'j`ai menti', 'je mentirai', 'que je mente']
# mesurer ['1st group']
# mettre ['3nd group', 'je mets, nous mettons', 'j’ai mis', 'je mettrai', 'que je mette ']
# mettre en adjudication []
# mettre en place de []
# mettre à l'entreprise []
# meubler ['1st group']
# meurtrir ['2nd group']
# miauler ['1st group']
# miner ['1st group']
# modeler ['1st group']
# modifier ['1st group']
# moisir ['2nd group']
# monopoliser ['1st group']
# monter ['1st group']
# monter à bicyclette []
# monter à cheval []
# monter à l'abordage []
# montrer ['1st group']
# mordre ['3nd group', 'je mords', 'j`ai mordu', 'je mordrai', 'que je morde']
# moudre ['3nd group', 'je mouds, nous moulons', 'j`ai moulu', 'je moudrai', 'que je moule']
# mouiller ['1st group']
# mourir ['3nd group', 'je meurs, nous mourons', 'je suis mort', 'je mourrai', 'que je meure, que nous mourions']
# mouvoir ['3nd group', 'je meus, nous mouvons', 'j`ai mû', 'je mouvrai', 'que je meuve']
# mugir ['2nd group']
# munir ['2nd group']
# murmurer ['1st group']
# mutiler ['1st group']
# mystifier ['1st group']
# mâcher ['1st group']
# méconnaître ['3nd group', 'je méconnais, nous méconnaissons', 'j’ai méconnu', 'je méconnaîtrai', 'que je méconnaisse']
# méditer ['1st group']
# mélanger ['1st group']
# ménager ['1st group']
# mépriser ['1st group']
# mériter ['1st group']
# mêler ['1st group']
# mûrir ['2nd group']
# nager ['1st group']
# natter ['1st group']
# naviguer ['1st group']
# naître ['3nd group', 'je nais, nous naissons', 'je suis né', 'je naîtrai', 'que je naisse']
# nettoyer ['1st group']
# nier ['1st group']
# noircir ['2nd group']
# nommer ['1st group']
# noter ['1st group']
# nouer ['1st group']
# nourrir ['2nd group']
# noyer ['1st group']
# nuire ['3nd group', 'je nuis, nous nuisons', 'j’ai nui', 'je nuirai', 'que je nuise ']
# négliger ['1st group']
# obliger ['1st group']
# obliger à []
# observer ['1st group']
# obséder ['1st group']
# obtenir ['3nd group', 'j`obtiens, nous obtenons', 'j`ai obtenu', 'j`obtiendrai', 'que j`obtienne']
# obéir ['2nd group']
# occuper ['1st group']
# offenser ['1st group']
# offrir ['3nd group', 'j`offre', 'j`ai offert', 'j`offrirai', 'que j`offre']
# omettre ['3nd group', 'j`omets, nous omettons', 'j’ai omis', 'j`omettrai', 'que j`omette ']
# ondoyer ['1st group']
# onduler ['1st group']
# opter ['1st group']
# opérer ['1st group']
# orchestrer ['1st group']
# organiser ['1st group']
# orner ['1st group']
# osciller ['1st group']
# oser ['1st group']
# oser attaquer []
# oser entreprendre []
# oublier ['1st group']
# ouvrir ['3nd group', 'j’ouvre, nous ouvrons', 'j’ai ouvert', 'j’ouvrirai', 'que j’ouvre']
# palper ['1st group']
# panser ['1st group']
# paralyser ['1st group']
# paraître ['3nd group', 'je parais, nous paraissons', 'j’ai paru', 'je paraîtrai', 'que je paraisse']
# parcourir ['3nd group', 'je parcours ', 'j’ai parcouru', 'je parcourrai', 'que je parcoure']
# pardonner ['1st group']
# parer ['1st group']
# parfumer ['1st group']
# parier ['1st group']
# parler ['1st group']
# parsemer ['1st group']
# partager ['1st group']
# participer ['1st group']
# partir ['3nd group', 'je pars, nous partons', 'je suis parti', 'je partirai', 'que je parte']
# parvenir ['3nd group', 'je parviens, nous parvenons', 'je suis parvenu', 'je parviendrai', 'que je parvienne, que nous parvenions']
# passer ['1st group']
# passer chez []
# passer la nuit []
# passer à tabac []
# patauger ['1st group']
# payer ['1st group']
# payer un premier acompte []
# peigner ['1st group']
# peindre ['3nd group', 'je peins, nous peignons', 'j`ai peint', 'je peindrai', 'que je peigne']
# peiner ['1st group']
# pelleter ['1st group']
# pencher ['1st group']
# pendre ['3nd group', 'je pends, nous pendons', 'j`ai pendu', 'je pendrai', 'que je pende']
# penser ['1st group']
# penser que []
# percer ['1st group']
# percevoir ['3nd group', 'je perçois, nous percevons', 'j’ai perçu', 'je percevrai', 'que je perçoive, que nous percevions']
# perdre ['3nd group', 'je perds', 'j`ai perdu', 'je perdrai', 'que je perde']
# permettre ['3nd group', 'je permets, nous permettons', 'j’ai permis', 'je permettrai', 'que je permette ']
# persister ['1st group']
# persuader ['1st group']
# persévérer ['1st group']
# perturber ['1st group']
# peser ['1st group']
# photographier ['1st group']
# piler ['1st group']
# piller ['1st group']
# piloter ['1st group']
# pincer ['1st group']
# piquer ['1st group']
# pisser ['1st group']
# piétiner ['1st group']
# placer ['1st group']
# placer d'argent []
# plaider ['1st group']
# plaindre ['3nd group', 'je plains, nous plaignons', 'j`ai plaint', 'je plaindrai', 'que je plaigne']
# plaire ['3nd group', 'je plais, nous plaisons', 'j`ai plu', 'je plairai', 'que je plaise']
# planer ['1st group']
# planter ['1st group']
# pleuvoir ['3nd group', 'il pleut', 'il a plu', 'il pleuvra', 'qu’il pleuve']
# plier ['1st group']
# plonger ['1st group']
# ployer ['1st group']
# polir ['2nd group']
# pomper ['1st group']
# porter ['1st group']
# porter plainte []
# poser ['1st group']
# poser une question []
# posséder ['1st group']
# pourchasser ['1st group']
# pourrir ['2nd group']
# poursuivre ['3nd group', 'je poursuis, nous poursuivons', 'j`ai poursuivi', 'je poursuivrai', 'que je poursuive']
# pourvoir ['3nd group', 'je pourvois, nous pourvoyons', 'j`ai pourvu', 'je pourvoirai', 'je pourvoie']
# pousser ['1st group']
# pousser à []
# pouvoir ['3nd group', 'je peux, nous pouvons', 'j`ai pu', 'je pourrai', 'que je puisse']
# pratiquer ['1st group']
# prendre ['3nd group', 'je prends, nous prenons', 'j’ai pris', 'je prendrai', 'que je prenne, que nous prenions']
# prendre dans les bras []
# prendre fin []
# prendre l'initiative []
# prendre la crémaillère []
# prendre part []
# prendre à bail []
# présenter ['1st group']
# presser ['1st group']
# presser le pas []
# prier ['1st group']
# proclamer ['1st group']
# procéder ['1st group']
# prodiguer ['1st group']
# produire ['3nd group', 'je produis, nous produisons', 'j`ai produit', 'je produirai', 'que je produise']
# profiter ['1st group']
# progresser ['1st group']
# projeter ['1st group']
# projeter un liquide []
# projeter une image []
# prolonger ['1st group']
# promettre ['3nd group', 'je promets, nous promettons', 'j’ai promis', 'je promettrai', 'que je promette ']
# promouvoir ['3nd group', 'je promeus, nous promouvons', 'j`ai promu', 'je promouvrai', 'que je promeuve']
# prononcer ['1st group']
# propager ['1st group']
# prospérer ['1st group']
# prostituer ['1st group']
# protester ['1st group']
# protéger ['1st group']
# prouver ['1st group']
# provenir ['3nd group', 'je proviens, nous provenons', 'je suis provenu', 'je proviendrai', 'que je provienne, que nous provenions']
# provoquer ['1st group']
# précipiter ['1st group']
# précéder ['1st group']
# prédire ['3nd group', 'je prédis, nous prédisons', 'j’ai prédit', 'je prédirai', 'que je prédise ']
# préférer ['1st group']
# prélever ['1st group']
# préoccuper ['1st group']
# préparer ['1st group']
# présenter ['1st group']
# préserver ['1st group']
# présider ['1st group']
# prétendre à []
# prétexter ['1st group']
# prévenir ['3nd group', 'je préviens, nous prévenons', 'j`ai prévenu', 'je préviendrai', 'que je prévienne, que nous prévenions']
# prévoir ['3nd group', 'je prévois, nous prévoyons', 'j’ai prévu', 'je prévoirai', 'que je prévoie, que nous prévoyions']
# prêcher ['1st group']
# prêter ['1st group']
# prêter serment []
# publier ['1st group']
# puiser ['1st group']
# punir ['2nd group']
# purifier ['1st group']
# pâlir ['2nd group']
# pécher ['1st group']
# pénétrer ['1st group']
# pépier ['1st group']
# périr ['2nd group']
# pérégriner ['1st group']
# péter ['1st group']
# pétrir ['2nd group']
# pêcher ['1st group']
# qualifier ['1st group']
# quitter ['1st group']
# raccommoder ['1st group']
# raccourcir ['2nd group']
# raconter ['1st group']
# raffiner ['1st group']
# rafler ['1st group']
# rafraîchir ['2nd group']
# raidir ['2nd group']
# railler ['1st group']
# ralentir ['2nd group']
# ramasser ['1st group']
# ramer ['1st group']
# rammasser ['1st group']
# ramper ['1st group']
# ranger ['1st group']
# rappeler ['1st group']
# rapper ['1st group']
# rapporter ['1st group']
# rapporter des propos []
# rapprocher ['1st group']
# raser ['1st group']
# rassembler ['1st group']
# rassurer ['1st group']
# rater ['1st group']
# rattraper ['1st group']
# ravager ['1st group']
# ravir ['2nd group']
# rayer ['1st group']
# rayonner ['1st group']
# rebondir ['2nd group']
# recevoir ['3nd group', 'je reçois, nous recevons', 'j’ai reçu', 'je recevrai', 'que je reçoive, que nous recevions']
# recevoir des visiteurs []
# recevoir officiellement []
# recevoir solennellement []
# rechercher ['1st group']
# recommander ['1st group']
# recommencer ['1st group']
# reconduire ['3nd group', 'je reconduis, nous reconduisons', 'j`ai reconduit', 'je reconduirai', 'que je reconduise']
# reconnaître ['3nd group', 'je reconnais, nous reconnaissons', 'j’ai reconnu', 'je reconnaîtrai', 'que je reconnaisse']
# recourir à []
# recouvrer ['1st group']
# recouvrir ['3nd group', 'j’ouvre, nous ouvrons', 'j’ai ouvert', 'j’ouvrirai', 'que j’ouvre']
# recruter ['1st group']
# rectifier ['1st group']
# recueiller ['1st group']
# recueillir ['3nd group', 'je recueille', 'j`ai recueilli', 'je recueillerai', 'que je recueille']
# reculer ['1st group']
# redire ['3nd group', 'je dis, nous disons', 'j’ai dit', 'je dirai', 'que je dise ']
# redoubler ['1st group']
# redouter ['1st group']
# redresser ['1st group']
# redresser un jugement []
# refaire ['3nd group', 'je refais, nous refaisons', 'j’ai refait', 'je referai', 'que je refasse, que nous refassions']
# refléter ['1st group']
# reformer ['1st group']
# refroidir ['2nd group']
# refuser ['1st group']
# regagner ['1st group']
# regarder ['1st group']
# regarder bouche bée []
# regarder un spectacle []
# regretter ['1st group']
# rejeter ['1st group']
# rejeter de la nourriture []
# rejeter par intolérance []
# rejoindre ['3nd group', 'je rejoins, nous rejoignons', 'j`ai rejoint', 'je rejoindrai', 'que je rejoigne']
# relier ['1st group']
# relire ['3nd group', 'je relis', 'j’ai relu', 'je relirai', 'que je relise ']
# rellier ['1st group']
# relâcher ['1st group']
# rembourrer ['1st group']
# rembourser ['1st group']
# remercier ['1st group']
# remonter ['1st group']
# remplacer ['1st group']
# remplir ['2nd group']
# remporter ['1st group']
# remuer ['1st group']
# remédier ['1st group']
# rencontrer ['1st group']
# rendre ['3nd group', 'je rends, nous rendons', 'j`ai rendu', 'je rendrai', 'que je rende']
# rendre confus []
# rendre plus beau []
# rendre trouble []
# renfermer ['1st group']
# renoncer ['1st group']
# renouveler ['1st group']
# renseigner ['1st group']
# renverser ['1st group']
# renvoyer ['1st group']
# repasser ['1st group']
# reporter ['1st group']
# repousser ['1st group']
# reprendre ['3nd group', 'je reprends, nous reprenons', 'j’ai repris', 'je reprendrai', 'que je reprenne, que nous reprenions']
# reprocher ['1st group']
# représenter ['1st group']
# requérir ['3nd group', 'je requiers, nous requérons', 'j`ai requis', 'je requerrai', 'que je requière']
# respecter ['1st group']
# respirer ['1st group']
# respondre []
# ressembler ['1st group']
# ressentir ['3nd group', 'je ressens, nous ressentons', 'j`ai ressenti', 'je ressentirai', 'que je ressente']
# restaurer ['1st group']
# rester ['1st group']
# rester en arrière []
# retarder ['1st group']
# retenir ['3nd group', 'je retiens, nous retenons', 'j`ai retenu', 'je retiendrai', 'que je retienne']
# retirer ['1st group']
# retomber ['1st group']
# retourner ['1st group']
# retrancher ['1st group']
# revenir ['3nd group', 'je reviens, nous revenons', 'je suis revenu', 'je reviendrai', 'que je revienne, que nous revenions']
# revenir toujours sur la même chapitre []
# revenir à []
# revoir ['3nd group', 'je revois, nous revoyons', 'j’ai revu', 'je reverrai', 'que je revoie, que nous revoyions']
# revêtir ['3nd group', 'je revêts, nous revêtons', 'j`ai revêtu', 'je revêtirai', 'que je revête, que nous revêtions']
# ricaner ['1st group']
# rider ['1st group']
# rincer ['1st group']
# rire ['3nd group', 'je ris ', 'j’ai ri', 'je rirai', 'que je rie, que nous riions']
# risquer ['1st group']
# rivaliser ['1st group']
# roder ['1st group']
# rompre ['3nd group', 'je romps', 'j`ai rompu', 'je romprai', 'que je rompe']
# ronfler ['1st group']
# ronger ['1st group']
# ronronner ['1st group']
# rosser ['1st group']
# roter ['1st group']
# rougir ['2nd group']
# rouler ['1st group']
# rouspéter ['1st group']
# rucher ['1st group']
# ruiner ['1st group']
# ruminer ['1st group']
# râler ['1st group']
# râper ['1st group']
# râteler ['1st group']
# réaliser ['1st group']
# réciter ['1st group']
# réclamer ['1st group']
# récolter ['1st group']
# récompenser ['1st group']
# réconforter ['1st group']
# récupérer ['1st group']
# récurer ['1st group']
# rédiger ['1st group']
# réduire ['3nd group', 'je réduis, nous réduisons', 'j`ai réduit', 'je réduirai', 'que je réduise']
# réduire en miettes []
# réfléchir ['2nd group']
# réformer ['1st group']
# réfuter ['1st group']
# régaler ['1st group']
# régler ['1st group']
# régner ['1st group']
# réjouir ['2nd group']
# répandre ['3nd group', 'je répands, nous répandons', 'j`ai répandu', 'je répandrai', 'que je répande']
# réparer ['1st group']
# répartir ['2nd group']
# répondre ['3nd group', 'je réponds', 'j`ai répondu', 'je répondrai', 'que je réponde']
# réprimander ['1st group']
# réprimer ['1st group']
# répéter ['1st group']
# réserver ['1st group']
# réserver pour []
# résigner ['1st group']
# résister ['1st group']
# résonner ['1st group']
# résoudre ['3nd group', 'je résous, nous résolvons', 'j`ai résous', 'je résoudrai', 'que je résolve']
# résulter ['1st group']
# résumer ['1st group']
# rétorquer ['1st group']
# réunir ['2nd group']
# réussir ['2nd group']
# réveiller ['1st group']
# réviser ['1st group']
# révéler ['1st group']
# rêver ['1st group']
# rêver éveillé []
# rôder ['1st group']
# rôtir ['2nd group']
# s'abaisser ['1st group']
# s'abattre []
# s'abonner ['1st group']
# s'aboucher avec []
# s'abouler ['1st group']
# s'abriter ['1st group']
# s'absenter ['1st group']
# s'abstenir ['2nd group']
# s'abstenir de []
# s'abâtardir ['2nd group']
# s'abêtir ['2nd group']
# s'abîmer ['1st group']
# s'acclimater ['1st group']
# s'accorder ['1st group']
# s'accoter ['1st group']
# s'accoupler ['1st group']
# s'accoutumer ['1st group']
# s'accoître []
# s'accroître []
# s'acidifier ['1st group']
# s'adapter ['1st group']
# s'adjoindre des aides []
# s'adosser ['1st group']
# s'adresser à []
# s'affilier ['1st group']
# s'agenouiller ['1st group']
# s'agglutiner ['1st group']
# s'aigrir ['2nd group']
# s'ajuster ['1st group']
# s'allumer ['1st group']
# s'amoindrir ['2nd group']
# s'amuser ['1st group']
# s'apercevoir ['2nd group']
# s'apitoyer ['1st group']
# s'appeler ['1st group']
# s'approcher ['1st group']
# s'arrêter ['1st group']
# s'arrêter à []
# s'attabler ['1st group']
# s'avancer ['1st group']
# s'efforcer ['1st group']
# s'en aller []
# s'enfuir ['2nd group']
# s'engager ['1st group']
# s'enivrer ['1st group']
# s'ennuyer ['1st group']
# s'enrhumer ['1st group']
# s'entremettre []
# s'excuser ['1st group']
# s'habiller ['1st group']
# s'harmoniser ['1st group']
# s'humilier ['1st group']
# s'incliner ['1st group']
# s'indigner ['1st group']
# s'indigner de []
# s'informer ['1st group']
# s'intéresser ['1st group']
# s'obstiner ['1st group']
# s'occuper ['1st group']
# s'occuper de []
# s'ébattre []
# s'échapper ['1st group']
# s'élancer ['1st group']
# s'ériger en []
# s'étendre []
# s'étonner ['1st group']
# s'évanouir ['2nd group']
# s'éveiller ['1st group']
# saisir ['2nd group']
# saler ['1st group']
# salir ['2nd group']
# saluer ['1st group']
# saper ['1st group']
# sarcler ['1st group']
# satisfaire ['3nd group', 'je satisfais, nous satisfaisons', 'j’ai satisfait', 'je satisferai', 'que je satisfasse, que nous satisfassions']
# saturer ['1st group']
# saucer ['1st group']
# sauter ['1st group']
# sauter à l'abordage []
# sautiller ['1st group']
# sauvegarder ['1st group']
# sauver ['1st group']
# savoir ['3nd group', 'je sais, nous savons', 'j’ai su', 'je saurai', 'que je sache, que nous sachions']
# savourer ['1st group']
# sceller ['1st group']
# scier ['1st group']
# scintiller ['1st group']
# se bagarrer ['is conjugated like bagarrer']
# se baigner ['is conjugated like baigner']
# se battre ['is conjugated like battre']
# se comporter ['is conjugated like comporter']
# se conduire ['is conjugated like conduire']
# se conformer ['is conjugated like conformer']
# se coucher ['is conjugated like coucher']
# se disputer ['is conjugated like disputer']
# se douter de ['is conjugated like douter']
# se dresser ['is conjugated like dresser']
# se débattre ['is conjugated like débattre']
# se délecter ['is conjugated like délecter']
# se démener ['is conjugated like démener']
# se déplacer ['is conjugated like déplacer']
# se dépêcher ['is conjugated like dépêcher']
# se déshabiller ['is conjugated like déshabiller']
# se dévouer ['is conjugated like dévouer']
# se faner ['is conjugated like faner']
# se fatiguer ['is conjugated like fatiguer']
# se fier ['is conjugated like fier']
# se fier à ['is conjugated like fier']
# se lamenter ['is conjugated like lamenter']
# se lever ['is conjugated like lever']
# se marier ['is conjugated like marier']
# se masturber ['is conjugated like masturber']
# se mettre d'accord ['is conjugated like mettre']
# se mettre en tranvers ['is conjugated like mettre']
# se mettre en travers ['is conjugated like mettre']
# se mettre à l'abri ['is conjugated like mettre']
# se mettre à l'abri de ['is conjugated like mettre']
# se méfier ['is conjugated like méfier']
# se moquer ['is conjugated like moquer']
# se parler ['is conjugated like parler']
# se perdre ['is conjugated like perdre']
# se plaindre ['is conjugated like plaindre']
# se porter ['is conjugated like porter']
# se presser ['is conjugated like presser']
# se promener ['is conjugated like promener']
# se précipiter ['is conjugated like précipiter']
# se quereller ['is conjugated like quereller']
# se racornir ['is conjugated like racornir']
# se rappeler ['is conjugated like rappeler']
# se ratatiner ['is conjugated like ratatiner']
# se recommander ['is conjugated like recommander']
# se relâcher ['is conjugated like relâcher']
# se rendre compte ['is conjugated like rendre']
# se repentir ['3nd group', 'je me repens, nous nous repentons', 'je me suis repenti', 'je me repentirai', 'que je me repente']
# se reposer ['is conjugated like reposer']
# se retirer ['is conjugated like retirer']
# se retrancher ['is conjugated like retrancher']
# se réfugier ['is conjugated like réfugier']
# se réjouir ['is conjugated like réjouir']
# se réserver ['is conjugated like réserver']
# se résigner ['is conjugated like résigner']
# se résoudre à ['is conjugated like résoudre']
# se réveiller ['is conjugated like réveiller']
# se révolter ['is conjugated like révolter']
# se servir de ['is conjugated like servir']
# se soulever ['is conjugated like soulever']
# se souvenir ['3nd group', 'je me souviens, nous nous souvenons', 'je me suis souvenu', 'je me souviendrai', 'que je me souvienne, que nous nous souvenions']
# se suicider ['is conjugated like suicider']
# se surveiller ['is conjugated like surveiller']
# se taire ['is conjugated like taire']
# se terminer ['is conjugated like terminer']
# se tromper ['is conjugated like tromper']
# se trouver ['is conjugated like trouver']
# secouer ['1st group']
# secourir ['3nd group', 'je secours ', 'j’ai secouru', 'je secourrai', 'que je secoure']
# sectionner ['1st group']
# sembler ['1st group']
# semer ['1st group']
# sentir ['3nd group', 'je sens, nous sentons', 'j`ai senti', 'je sentirai', 'que je sente']
# sermonner ['1st group']
# serrer ['1st group']
# serrer plus fort []
# servir ['3nd group', 'je sers, nous servons', 'j`ai servi', 'je servirai', 'que je serve']
# siffler ['1st group']
# signaler ['1st group']
# signer ['1st group']
# signifier ['1st group']
# situer ['1st group']
# sièger ['1st group']
# soigner ['1st group']
# solliciter ['1st group']
# sommer ['1st group']
# songer ['1st group']
# sonner ['1st group']
# sonner à la porte []
# sorter ['1st group']
# sortir de []
# souder ['1st group']
# souffler ['1st group']
# souffler sur []
# souffrir ['3nd group', 'je souffre', 'j`ai souffert', 'je souffrirai', 'que je souffre']
# souhaiter ['1st group']
# souiller ['1st group']
# soulager ['1st group']
# soulever ['1st group']
# souligner ['1st group']
# soumettre ['3nd group', 'je soumets, nous soumettons', 'j’ai soumis', 'je soumettrai', 'que je soumette ']
# soupirer ['1st group']
# soupçonner ['1st group']
# sourire ['3nd group', 'je souris ', 'j’ai souri', 'je sourirai', 'que je sourie, que nous souriions']
# soustraire ['3nd group', 'je soustrais, nous soustrayons', 'j`ai soustrait', 'je soustrairai', 'que je soustraie, que nous soustrayions']
# soutenir ['3nd group', 'je soutiens, nous soutenons', 'j`ai soutenu', 'je soutiendrai', 'que je soutienne']
# stagner ['1st group']
# stationner ['1st group']
# stimuler ['1st group']
# stupéfier ['1st group']
# subir ['2nd group']
# substituer ['1st group']
# sucer ['1st group']
# suer ['1st group']
# suffire ['3nd group', 'je suffis', 'j`ai suffi', 'je suffirai', 'que je suffise']
# suffoquer ['1st group']
# suggérer ['1st group']
# suivre ['3nd group', 'je suis, nous suivons', 'j`ai suivi', 'je suivrai', 'que je suive']
# suivre un régime []
# supporter ['1st group']
# supposer ['1st group']
# supprimer ['1st group']
# surgir ['2nd group']
# surmonter ['1st group']
# surprendre ['3nd group', 'je surprends, nous surprenons', 'j’ai surpris', 'je surprendrai', 'que je surprenne, que nous surprenions']
# sursauter ['1st group']
# surveiller ['1st group']
# suspecter ['1st group']
# suspendre ['3nd group', 'je suspends, nous suspendons', 'j`ai suspendu', 'je suspendrai', 'que je suspende']
# sussurer ['1st group']
# sécher ['1st group']
# séparer ['1st group']
# tamiser ['1st group']
# taper ['1st group']
# tapisser ['1st group']
# taquiner ['1st group']
# tarder ['1st group']
# tasser ['1st group']
# taxer ['1st group']
# teindre ['3nd group', 'je teins, nous teignons', 'j`ai teint', 'je teindrai', 'que je teigne']
# tendre ['3nd group', 'je tends, nous tendons', 'j`ai tendu', 'je tendrai', 'que je tende']
# tendre un piège []
# tenir ['3nd group', 'je tiens, nous tenons', 'j`ai tenu', 'je tiendrai', 'que je tienne']
# tenir place de []
# tenter ['1st group']
# terminer ['1st group']
# terrer ['1st group']
# tester ['1st group']
# tinter ['1st group']
# tirer ['1st group']
# tirer au sort []
# tirer un trait []
# tisser ['1st group']
# tolérer ['1st group']
# tomber ['1st group']
# tondre ['3nd group', 'je tonds', 'j`ai tondu', 'je tondrai', 'que je tonde']
# tonner ['1st group']
# tordre ['3nd group', 'je tords', 'j`ai tordu', 'je tordrai', 'que je torde']
# torpiller ['1st group']
# toucher ['1st group']
# toucher à []
# tourbilloner ['1st group']
# tourmenter ['1st group']
# tourner ['1st group']
# tousser ['1st group']
# traduire ['3nd group', 'je traduis, nous traduisons', 'j`ai traduit', 'je traduirai', 'que je traduise']
# trahir ['2nd group']
# traire ['3nd group', 'je trais, nous trayons', 'j`ai trait', 'je trairai', 'que je traie, que nous trayions']
# traiter ['1st group']
# tramer ['1st group']
# trancher ['1st group']
# transformer ['1st group']
# transpirer ['1st group']
# transporter ['1st group']
# travailler ['1st group']
# traîner ['1st group']
# trembler ['1st group']
# tremper ['1st group']
# tresser ['1st group']
# tricher ['1st group']
# tricoter ['1st group']
# trier ['1st group']
# triompher ['1st group']
# tromper ['1st group']
# trotter ['1st group']
# troubler ['1st group']
# trouver ['1st group']
# trébucher ['1st group']
# tuer ['1st group']
# tutoyer ['1st group']
# tâter ['1st group']
# télécharger ['1st group']
# téléphoner ['1st group']
# témoigner ['1st group']
# unir ['2nd group']
# uriner ['1st group']
# user ['1st group']
# user de []
# usurper ['1st group']
# vacciner ['1st group']
# vaciller ['1st group']
# vaguer ['1st group']
# vaincre ['3nd group', 'je vaincs, nous vainquons', 'j`ai vaincu', 'je vaincrai', 'que je vainque']
# valoir ['3nd group', 'je vaux, nous valons', 'j`ai valu', 'je vaudrai', 'que je vaille, que nous valions']
# varier ['1st group']
# veiller sur []
# veiller à []
# vendre ['3nd group', 'je vends, nous vendons', 'j`ai vendu', 'je vendrai', 'que je vende']
# vendre d'occasion []
# venger ['1st group']
# venir ['3nd group', 'je viens, nous venons', 'je suis venu', 'je viendrai', 'que je vienne, que nous venions']
# ventiler ['1st group']
# verrouiller ['1st group']
# verser ['1st group']
# verser un premier acompte []
# vibrer ['1st group']
# vider ['1st group']
# violer ['1st group']
# virer ['1st group']
# viser ['1st group']
# visiter ['1st group']
# vivre ['3nd group', 'je vis, nous vivons', 'j’ai vécu', 'je vivrai', 'que je vive']
# voiler ['1st group']
# voir ['3nd group', 'je vois, nous voyons', 'j’ai vu', 'je verrai', 'que je voie, que nous voyions']
# voler ['1st group']
# voltiger ['1st group']
# vomir ['2nd group']
# vouloir ['3nd group', 'je veux, nous voulons', 'j’ai voulu', 'je voudrai', 'que je veuille, que nous voulions']
# voyager ['1st group']
# voyager au loin []
# vrombir ['2nd group']
# végéter ['1st group']
# vérifier ['1st group']
# vêtir ['3nd group', 'je vêts, nous vêtons', 'j`ai vêtu', 'je vêtirai', 'que je vête, que nous vêtions']
# zapper ['1st group']
# ébouriffer ['1st group']
# échapper ['1st group']
# échapper comme une anguille []
# échauder ['1st group']
# économiser ['1st group']
# écouter ['1st group']
# écrire ['3nd group', 'j`écris, nous écrivons', 'j’ai écrit', 'j’écrirai', 'que j’écrive']
# éditer ['1st group']
# épuiser ['1st group']
# étudier ['1st group']
# évaluer ['1st group']
# éviter ['1st group']
# être ['3nd group', 'je suis, nous sommes', 'j’ai été', 'je serai', 'que je sois, que nous soyons']
# être accro []
# être accroupi []
# être assis []
# être bon à []
# être composé de []
# être couché []
# être d'avis []
# être de service []
# être debout []
# être différent []
# être décent []
# être efficace []
# être en colère []
# être en feu []
# être en relation avec []
# être en retard []
# être fou []
# être habitué à []
# être indulgent []
# être joyeux []
# être lumineux []
# être présent []
# être situé []
# être spectateur de []
# être urgent []
# être vacant []
# ôter ['1st group']

# %%
# прогоняем identify() по всем глаголам и добавляем нужные поля
for i in entries:
    if i.xpath('.//pos/text()') == ['v']:
        lst = identify(str(i.xpath('.//orth/text()'))[2:-2])
        if len(lst)>0:
            etree.SubElement(i.xpath('.//gramGrp')[0], 'subc').text = lst[0]
            if len(lst)>1:
                new = etree.SubElement(i, 'form')
                new.set('type', 'inflected')
                for j in lst[1:]:
                    etree.SubElement(new, 'orth').text = j
                i.append(new)

# %%
# наводим красоту
def indent(elem, level=0):
    i = "\n" + level*"  "
    if len(elem):
        if not elem.text or not elem.text.strip():
            elem.text = i + "  "
        if not elem.tail or not elem.tail.strip():
            elem.tail = i
        for elem in elem:
            indent(elem, level+1)
        if not elem.tail or not elem.tail.strip():
            elem.tail = i
    else:
        if level and (not elem.tail or not elem.tail.strip()):
            elem.tail = i

indent(root)

# %%
# проверяем
print(etree.tostring(entries[-35], encoding='utf-8', pretty_print=True).decode())
print(etree.tostring(entries[5500], encoding='utf-8', pretty_print=True).decode())
# Out:
# <entry>
#         <form>
#           <orth>être</orth>
#           <pron>ɛtʀ</pron>
#         </form>
#         <gramGrp>
#           <pos>v</pos>
#           <subc>3nd group</subc>
#         </gramGrp>
#         <sense>
#           <cit type="trans">
#             <quote>be</quote>
#           </cit>
#         </sense>
#         <form type="inflected">
#           <orth>je suis, nous sommes</orth>
#           <orth>j’ai été</orth>
#           <orth>je serai</orth>
#           <orth>que je sois, que nous soyons</orth>
#         </form>
#       </entry>
#
#
# <entry>
#         <form>
#           <orth>mêler</orth>
#           <pron>mɛle</pron>
#         </form>
#         <gramGrp>
#           <pos>v</pos>
#           <subc>1st group</subc>
#         </gramGrp>
#         <sense>
#           <cit type="trans">
#             <quote>blend</quote>
#           </cit>
#           <cit type="trans">
#             <quote>mingle</quote>
#           </cit>
#           <cit type="trans">
#             <quote>mix</quote>
#           </cit>
#           <cit type="trans">
#             <quote>shuffle</quote>
#           </cit>
#         </sense>
#       </entry>

# %%
# записываем результат в файл
et = etree.ElementTree(root)
et.write('fra-eng_parsed.tei', encoding = 'utf-8', pretty_print=True)
